# %% [markdown]
# # Introduction:
# This is code tests Knowledge Distillation (KD) technique on the Primary breast cancer vs Normal breast tissue (PBCNT) with oversampling.
#
# Please remember to cite our work.
#
# Thank you.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %matplotlib inline 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, MaxPool1D,Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils



#Import models from scikit learn module:
from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


#For Timing the simulation
import time

# %% [markdown]
# # Parameters

# %%
epoch=50          #training epoch

# %% [markdown]
# # Loading Data

# %%
#load dataset
#data = pd.read_csv("/kaggle/input/breast-cancer-wisconsin-data/data.csv",header = 0)
data = pd.read_csv("/kaggle/input/primary-breast-cancer-vs-normal-breast-tissue/GSE58606_data.csv",header = 0)
data.head(5)
# Out:
#    4040 : hsa-miR-9-5p  4610 : hsa-miR-126-3p  4700 : hsa-miR-140-5p  \
# 0             6.877643               8.080215               6.245265
# 1             6.544287               6.882722               5.874236
# 2             6.879713               6.885387               5.958748
# 3             6.943464               7.972342               6.026106
# 4             7.097877               9.014977               7.127656
#
#    5250 : hsa-miR-105-5p  6880 : hsa-miR-297  9938 : hsa-let-7i-5p  \
# 0               6.304782            6.686064              7.805950
# 1               6.324987            6.638048              6.946567
# 2               6.317687            6.664956              7.266728
# 3               6.425266            6.761433              8.010618
# 4               6.566482            6.990273              8.746360
#
#    10138 : hsa-miR-130a-3p  10306 : hsa-miR-146b-5p  \
# 0                 6.814781                 7.146955
# 1                 6.488574                 6.690773
# 2                 6.965078                 6.969818
# 3                 6.441945                 6.679714
# 4                 8.087122                 7.680249
#
#    10901 : hsa_negative_control_6  10902 : hsa_negative_control_7  ...  \
# 0                        6.170680                        6.129586  ...
# 1                        6.160272                        6.104929  ...
# 2                        6.226957                        6.124874  ...
# 3                        6.471518                        6.264685  ...
# 4                        6.499892                        6.226560  ...
#
#    169411 : hsa-miR-205-3p  169412 : hsa-miR-1260a  169414 : hsa-miR-525-5p  \
# 0                 7.176684                7.724408                 6.035476
# 1                 7.249094                7.308890                 6.021796
# 2                 7.404104                7.466418                 5.977962
# 3                 6.811846                8.601204                 6.021790
# 4                 6.361862                7.570751                 5.967819
#
#    169415 : hsa-miR-187-5p  169416 : hsa-miRPlus-A1086  \
# 0                 6.255048                    6.572019
# 1                 6.902473                    6.347183
# 2                 6.484571                    6.259788
# 3                 5.912640                    6.002302
# 4                 5.821186                    6.550078
#
#    169417 : hsa-miR-551b-5p  169419 : hsa-miR-300  169420 : hsa-miR-193b-5p  \
# 0                  6.251777              5.873303                  6.362097
# 1                  6.625569              6.004899                  6.560329
# 2                  6.226957              5.815442                  6.354622
# 3                  5.999349              5.811117                  6.306704
# 4                  5.947994              5.828413                  6.288596
#
#    target          target_actual
# 0       1  primary breast cancer
# 1       1  primary breast cancer
# 2       1  primary breast cancer
# 3       1  primary breast cancer
# 4       1  primary breast cancer
#
# [5 rows x 1928 columns]

# %% [markdown]
# # Data Preprocessing

# %%
print(data['target'].value_counts())
plt.title('Count of cancer type')
sns.countplot(data['target'])
plt.ylabel('Count')
plt.show()
# Out:
# target
# 1    122
# 0     11
# Name: count, dtype: int64

# %%
data.isnull().any().describe()
# Out:
# count      1928
# unique        1
# top       False
# freq       1928
# dtype: object

# %%
my_types=data.dtypes
print(my_types)
# Out:
# 4040 : hsa-miR-9-5p         float64
# 4610 : hsa-miR-126-3p       float64
# 4700 : hsa-miR-140-5p       float64
# 5250 : hsa-miR-105-5p       float64
# 6880 : hsa-miR-297          float64
#                              ...
# 169417 : hsa-miR-551b-5p    float64
# 169419 : hsa-miR-300        float64
# 169420 : hsa-miR-193b-5p    float64
# target                        int64
# target_actual                object
# Length: 1928, dtype: object

# %%
#clean and prepare data
data.drop('target_actual',axis=1,inplace=True)

# size of the dataframe
len(data)
# Out:
# 133

# %%
Y=data.target
data.drop('target',axis=1,inplace=True)

# %% [markdown]
# ## Scaling

# %%
# # Scale the data to be between -1 and 1
scaler = StandardScaler()
X=scaler.fit_transform(data)
del data

# %% [markdown]
# ## PCA

# %%
# from sklearn.decomposition import PCA
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(X)
# Out:
# array([[ 3.73924556e+01, -2.56167487e+00,  7.30588170e+00, ...,
#          2.70717184e-01, -1.38374107e-02,  1.08023611e-14],
#        [ 6.20060624e+01,  8.64799728e+00, -1.37279008e+01, ...,
#          2.06032658e-01,  1.69862171e-01,  1.08023611e-14],
#        [ 4.27974589e+01, -8.89053592e-01,  4.53431120e+00, ...,
#          7.67837484e-02,  8.21543843e-02,  1.08023611e-14],
#        ...,
#        [ 1.89555244e+01,  3.09969575e+01, -2.20139240e+01, ...,
#          1.08216998e-01,  9.81938664e-02,  1.08023611e-14],
#        [-3.60300690e+00,  1.13735087e+01, -1.54740550e+01, ...,
#         -1.41424487e-01,  1.99608091e-02,  1.08023611e-14],
#        [-3.85517604e+01, -9.14330008e-01,  4.05245984e+00, ...,
#         -5.21138266e-02, -1.74321305e-01,  1.08023611e-14]])

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([3.07222156e-01, 1.30148321e-01, 1.06324295e-01, 5.55860261e-02,
#        4.91634217e-02, 3.96844445e-02, 2.92768157e-02, 2.24030972e-02,
#        2.19006789e-02, 1.35255616e-02, 1.14600255e-02, 1.05191877e-02,
#        9.63962210e-03, 8.91863335e-03, 7.87503061e-03, 7.79767375e-03,
#        6.94336192e-03, 6.40445196e-03, 5.71985698e-03, 5.50284526e-03,
#        5.04743806e-03, 4.72009673e-03, 4.36804475e-03, 4.11410343e-03,
#        3.91428498e-03, 3.79988644e-03, 3.47605808e-03, 3.16027639e-03,
#        3.04227313e-03, 3.03474429e-03, 2.89355898e-03, 2.75298986e-03,
#        2.64633398e-03, 2.56621390e-03, 2.45112232e-03, 2.37984535e-03,
#        2.36566784e-03, 2.29609378e-03, 2.22758801e-03, 2.15366901e-03,
#        2.06366581e-03, 2.00760087e-03, 1.94551149e-03, 1.89681820e-03,
#        1.84025475e-03, 1.76952640e-03, 1.69235251e-03, 1.64926054e-03,
#        1.56893664e-03, 1.52711318e-03, 1.50235743e-03, 1.47802645e-03,
#        1.41906315e-03, 1.40585066e-03, 1.38303447e-03, 1.37410730e-03,
#        1.33228887e-03, 1.29561941e-03, 1.27520711e-03, 1.23814805e-03,
#        1.21672607e-03, 1.18916358e-03, 1.15728373e-03, 1.12381372e-03,
#        1.10402059e-03, 1.09540659e-03, 1.07492087e-03, 1.06439967e-03,
#        1.04385779e-03, 1.02253483e-03, 1.00477001e-03, 9.73643911e-04,
#        9.64900216e-04, 9.34021190e-04, 9.17767335e-04, 9.01011987e-04,
#        8.90923510e-04, 8.74468348e-04, 8.53462765e-04, 8.45226280e-04,
#        8.29153924e-04, 8.11485525e-04, 7.81710198e-04, 7.68558856e-04,
#        7.58535592e-04, 7.50193747e-04, 7.45975192e-04, 7.38900522e-04,
#        7.18218535e-04, 7.09219576e-04, 6.95852146e-04, 6.85082572e-04,
#        6.79886272e-04, 6.63769152e-04, 6.54287913e-04, 6.45325528e-04,
#        6.36971923e-04, 6.25007772e-04, 6.16577930e-04, 6.03432938e-04,
#        5.94632768e-04, 5.92238661e-04, 5.76585265e-04, 5.67263343e-04,
#        5.64610002e-04, 5.47791281e-04, 5.44270657e-04, 5.32238575e-04,
#        5.22786503e-04, 5.21036504e-04, 5.07599076e-04, 4.98255621e-04,
#        4.90957123e-04, 4.83462719e-04, 4.63955097e-04, 4.56368446e-04,
#        4.52708334e-04, 4.48804064e-04, 4.30030600e-04, 4.17092226e-04,
#        4.03818399e-04, 4.00803215e-04, 3.93958845e-04, 3.89234872e-04,
#        3.82127103e-04, 3.62960467e-04, 3.56261512e-04, 3.55483044e-04,
#        3.35663517e-04, 3.31381033e-04, 3.25371744e-04, 2.89241754e-04,
#        6.05872300e-32])

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(10, 6))
    plt.bar(range(133), explained_variance, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.grid(visible=True)
    plt.tight_layout()

# %%
pca=PCA(n_components=60)
X_new=pca.fit_transform(X)
X_new
# Out:
# array([[ 3.73924556e+01, -2.56167487e+00,  7.30588170e+00, ...,
#         -1.30303290e-01,  1.84180877e-02, -3.64239913e-01],
#        [ 6.20060624e+01,  8.64799728e+00, -1.37279008e+01, ...,
#         -1.08730418e+00,  4.16820042e+00,  3.89576762e+00],
#        [ 4.27974589e+01, -8.89053592e-01,  4.53431120e+00, ...,
#          2.45184067e+00,  2.33000296e+00, -2.71431898e+00],
#        ...,
#        [ 1.89555244e+01,  3.09969575e+01, -2.20139240e+01, ...,
#          3.11104920e+00, -4.09264514e+00,  1.34299591e+00],
#        [-3.60300690e+00,  1.13735087e+01, -1.54740550e+01, ...,
#         -9.04073528e-02, -1.59910033e+00, -9.10030466e-02],
#        [-3.85517604e+01, -9.14330009e-01,  4.05245985e+00, ...,
#         -4.12144280e-01, -7.39135816e-01, -2.15895048e-01]])

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.30722216, 0.13014832, 0.1063243 , 0.05558603, 0.04916342,
#        0.03968444, 0.02927682, 0.0224031 , 0.02190068, 0.01352556,
#        0.01146003, 0.01051919, 0.00963962, 0.00891863, 0.00787503,
#        0.00779767, 0.00694336, 0.00640445, 0.00571986, 0.00550284,
#        0.00504744, 0.00472009, 0.00436804, 0.0041141 , 0.00391428,
#        0.00379988, 0.00347603, 0.00316025, 0.00304218, 0.00303464,
#        0.00289342, 0.00275274, 0.00264617, 0.00256563, 0.00245061,
#        0.00237917, 0.00236553, 0.00229534, 0.00222725, 0.00215252,
#        0.00206279, 0.00200675, 0.00194378, 0.00189338, 0.0018365 ,
#        0.00176351, 0.00167314, 0.00164183, 0.00156105, 0.00152012,
#        0.00149775, 0.00147308, 0.00140606, 0.00138396, 0.00137123,
#        0.00134334, 0.00128822, 0.00126206, 0.00124876, 0.0012071 ])

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(10, 16))

    plt.bar(range(60), explained_variance, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.grid(True)
    plt.tight_layout()

# %%
X=X_new
X.shape, Y.shape
# Out:
# ((133, 60), (133,))

# %% [markdown]
# ## Applying Oversampling

# %%
from imblearn.over_sampling import KMeansSMOTE
oversample = KMeansSMOTE()
X_res, Y_res = oversample.fit_resample(X, Y)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
X.shape, Y.shape,X_res.shape,Y_res.shape
# Out:
# ((133, 60), (133,), (244, 60), (244,))

# %%
# summarize class distribution
Y1=pd.DataFrame(Y)   
Y2=pd.DataFrame(Y_res)
print(Y1.value_counts())
print(Y2.value_counts())
# Out:
# target
# 1         122
# 0          11
# Name: count, dtype: int64
# target
# 0         122
# 1         122
# Name: count, dtype: int64

# %% [markdown]
# ## Make Y one-hot

# %%
Y_res = utils.to_categorical(Y_res, num_classes=2)

# %% [markdown]
# ## Split train and test dataset

# %%
X_trainO,X_testO,y_trainO,y_testO= train_test_split(X_res,Y_res,test_size=0.15,stratify=Y_res)

# %% [markdown]
# ## Reshaping the data set to 3D to pass it through CNN

# %%
X_trainO.shape,X_testO.shape,y_trainO.shape,y_testO.shape
# Out:
# ((207, 60), (37, 60), (207, 2), (37, 2))

# %%
#X_trainO = X_trainO.reshape(610,30,1)
#X_testO = X_testO.reshape(108,30,1)

X_trainO = X_trainO.reshape(X_trainO.shape[0],X_trainO.shape[1],1)
X_testO = X_testO.reshape(X_testO.shape[0],X_testO.shape[1],1)

# %% [markdown]
# # Create teacher and student model

# %%
# Create the teacher
teacher =keras.Sequential()
teacher.add(keras.Input(shape=(X_trainO.shape[1],1)))
teacher.add(keras.layers.Conv1D(filters=64,kernel_size= 2,activation='relu'))
teacher.add(keras.layers.BatchNormalization())
teacher.add(keras.layers.Dropout(0.2))
        
teacher.add(keras.layers.Conv1D(448, 2,activation='relu'))
teacher.add(keras.layers.BatchNormalization())
teacher.add(keras.layers.Dropout(0.2))
        
teacher.add(keras.layers.Flatten())
teacher.add(keras.layers.Dense(64,activation='relu'))
teacher.add(keras.layers.Dropout(0.2))

teacher.add(keras.layers.Dense(2,activation='sigmoid'))

teacher.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',
              metrics=['accuracy'])


# Create the student
student = keras.Sequential(
    [
        keras.Input(shape=(X_trainO.shape[1], 1)),
        layers.Conv1D(4, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
       # layers.LeakyReLU(alpha=0.2),
        
        layers.Conv1D(8, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        
        layers.Flatten(),
        layers.Dense(2,activation='sigmoid'),
    ],
    name="student",)
    

# Clone student for later comparison
student_scratch = keras.models.clone_model(student)

# %% [markdown]
# Lets make a copy of the student model for comparion

# %%
teacher.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 59, 64)         │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 59, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 59, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 58, 448)        │        57,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 58, 448)        │         1,792 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 58, 448)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25984)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     1,663,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,723,202 (6.57 MB)
#  Trainable params: 1,722,178 (6.57 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
student.summary()
# Out:
# Model: "student"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 59, 4)          │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 59, 4)          │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 59, 4)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 58, 8)          │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 58, 8)          │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 58, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 464)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           930 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,062 (4.15 KB)
#  Trainable params: 1,038 (4.05 KB)
#  Non-trainable params: 24 (96.00 B)

# %% [markdown]
# # Teacher model Training

# %% [markdown]
# ## Teacher Oversampling

# %%
start_time = time.time()
teacher_historyO=teacher.fit(X_trainO,y_trainO,epochs=epoch,validation_data=(X_testO,y_testO),verbose=1)
end_time = time.time()
print( sep='\n')
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.7596 - loss: 0.5212 - val_accuracy: 0.6486 - val_loss: 0.4883
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9650 - loss: 0.0915 - val_accuracy: 0.7297 - val_loss: 0.4235
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9679 - loss: 0.0575 - val_accuracy: 0.8649 - val_loss: 0.3540
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9772 - loss: 0.0382 - val_accuracy: 0.9459 - val_loss: 0.2958
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.9730 - val_loss: 0.2565
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9730 - val_loss: 0.2215
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.9730 - val_loss: 0.1862
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.1564
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.1332
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.1141
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0988
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0864
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0763
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0678
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0601
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0542
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9730 - val_loss: 0.0498
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9730 - val_loss: 0.0458
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9730 - val_loss: 0.0433
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9730 - val_loss: 0.0418
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9730 - val_loss: 0.0384
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 8.0426e-04 - val_accuracy: 0.9730 - val_loss: 0.0343
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9730 - val_loss: 0.0302
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 6.7281e-04 - val_accuracy: 1.0000 - val_loss: 0.0266
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 8.9146e-04 - val_accuracy: 1.0000 - val_loss: 0.0247
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.1339e-04 - val_accuracy: 1.0000 - val_loss: 0.0205
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 8.0398e-04 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 7.2108e-04 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 8.2125e-04 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 4.9672e-04 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 3.5356e-04 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 3.7478e-04 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 5.0497e-04 - val_accuracy: 1.0000 - val_loss: 0.0168
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 5.8926e-04 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 2.9507e-04 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 2.4651e-04 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 5.1988e-04 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 2.1671e-04 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 2.4277e-04 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 4.3101e-04 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 4.0573e-04 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.8983e-04 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 5.5126e-04 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 2.1484e-04 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 3.9723e-04 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.8564e-04 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 4.5710e-04 - val_accuracy: 1.0000 - val_loss: 0.0054

# %% [markdown]
# ## Teacher Accuracy Oversampling

# %%
teacher.evaluate(X_testO,y_testO)
print("Execution time: ", end_time - start_time,"secs")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0038
# Execution time:  18.84263038635254 secs

# %% [markdown]
# # Student model Training

# %% [markdown]
# ## Creating Student (SM_Scratch) Model

# %%
#compile STUDENT
student_scratch.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',
          metrics=['accuracy'])
print( sep='\n')
print('STUDENT')
# Out:
# STUDENT

# %% [markdown]
# ## Student training

# %%
start_time = time.time()
student_scratch_historyO=student_scratch.fit(X_trainO,y_trainO,epochs=epoch,validation_data=(X_testO,y_testO),verbose=1)
end_time = time.time()
print( sep='\n')
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3007 - loss: 1.2228 - val_accuracy: 0.3514 - val_loss: 1.9204
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3807 - loss: 1.0896 - val_accuracy: 0.3784 - val_loss: 1.6385
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3438 - loss: 1.1163 - val_accuracy: 0.3784 - val_loss: 1.4549
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3669 - loss: 1.1007 - val_accuracy: 0.3784 - val_loss: 1.3209
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3998 - loss: 1.0912 - val_accuracy: 0.3784 - val_loss: 1.2152
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3758 - loss: 1.0543 - val_accuracy: 0.3784 - val_loss: 1.1284
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4287 - loss: 0.9715 - val_accuracy: 0.3784 - val_loss: 1.0550
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5162 - loss: 0.9781 - val_accuracy: 0.3784 - val_loss: 0.9914
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5321 - loss: 0.9159 - val_accuracy: 0.5676 - val_loss: 0.9368
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5537 - loss: 0.9454 - val_accuracy: 0.7027 - val_loss: 0.8889
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5886 - loss: 0.8166 - val_accuracy: 0.8378 - val_loss: 0.8451
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5822 - loss: 0.7991 - val_accuracy: 0.8378 - val_loss: 0.8063
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6937 - loss: 0.7100 - val_accuracy: 0.8378 - val_loss: 0.7713
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5953 - loss: 0.7926 - val_accuracy: 0.8108 - val_loss: 0.7393
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5384 - loss: 0.8189 - val_accuracy: 0.8108 - val_loss: 0.7094
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6685 - loss: 0.7553 - val_accuracy: 0.8108 - val_loss: 0.6833
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6665 - loss: 0.7167 - val_accuracy: 0.8108 - val_loss: 0.6598
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6384 - loss: 0.7321 - val_accuracy: 0.8108 - val_loss: 0.6382
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7505 - loss: 0.6363 - val_accuracy: 0.8108 - val_loss: 0.6182
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6894 - loss: 0.7083 - val_accuracy: 0.8108 - val_loss: 0.6002
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6760 - loss: 0.6584 - val_accuracy: 0.8108 - val_loss: 0.5837
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7450 - loss: 0.6216 - val_accuracy: 0.8378 - val_loss: 0.5683
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7361 - loss: 0.6136 - val_accuracy: 0.8378 - val_loss: 0.5543
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7844 - loss: 0.5898 - val_accuracy: 0.8378 - val_loss: 0.5415
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7113 - loss: 0.6388 - val_accuracy: 0.8378 - val_loss: 0.5295
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7591 - loss: 0.5695 - val_accuracy: 0.8378 - val_loss: 0.5183
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7709 - loss: 0.5590 - val_accuracy: 0.8378 - val_loss: 0.5080
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7301 - loss: 0.5212 - val_accuracy: 0.8649 - val_loss: 0.4986
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7667 - loss: 0.5735 - val_accuracy: 0.8649 - val_loss: 0.4900
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7808 - loss: 0.5072 - val_accuracy: 0.8649 - val_loss: 0.4825
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7610 - loss: 0.5321 - val_accuracy: 0.8649 - val_loss: 0.4757
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7663 - loss: 0.5200 - val_accuracy: 0.8649 - val_loss: 0.4692
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7383 - loss: 0.5393 - val_accuracy: 0.8649 - val_loss: 0.4630
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8030 - loss: 0.4776 - val_accuracy: 0.8649 - val_loss: 0.4574
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8395 - loss: 0.4898 - val_accuracy: 0.8649 - val_loss: 0.4516
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7851 - loss: 0.4716 - val_accuracy: 0.8649 - val_loss: 0.4464
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7949 - loss: 0.5246 - val_accuracy: 0.8649 - val_loss: 0.4416
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8030 - loss: 0.5175 - val_accuracy: 0.8649 - val_loss: 0.4370
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8086 - loss: 0.4816 - val_accuracy: 0.8649 - val_loss: 0.4327
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8169 - loss: 0.4431 - val_accuracy: 0.8649 - val_loss: 0.4286
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8055 - loss: 0.4763 - val_accuracy: 0.8649 - val_loss: 0.4247
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8043 - loss: 0.4585 - val_accuracy: 0.8649 - val_loss: 0.4208
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7828 - loss: 0.4815 - val_accuracy: 0.8649 - val_loss: 0.4168
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8724 - loss: 0.4123 - val_accuracy: 0.8649 - val_loss: 0.4132
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8534 - loss: 0.4137 - val_accuracy: 0.8649 - val_loss: 0.4098
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7946 - loss: 0.4351 - val_accuracy: 0.8649 - val_loss: 0.4065
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8466 - loss: 0.4548 - val_accuracy: 0.8649 - val_loss: 0.4035
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8371 - loss: 0.4034 - val_accuracy: 0.8649 - val_loss: 0.4005
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8429 - loss: 0.4006 - val_accuracy: 0.8649 - val_loss: 0.3975
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8341 - loss: 0.4214 - val_accuracy: 0.8649 - val_loss: 0.3947

# %% [markdown]
# ## Student Accuracy Oversampling

# %%
# Generate generalization
student_scratch.evaluate(X_testO,y_testO)
print("Execution time: ", end_time - start_time,"secs")
print( sep='\n')
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8578 - loss: 0.3966
# Execution time:  6.6607489585876465 secs

# %% [markdown]
# # Construct distiller class

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)
            distillation_loss = self.distillation_loss_fn(
                tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                tf.nn.softmax(student_predictions / self.temperature, axis=1),
            )
            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results
    
    def call(self, x):
        return self.student(x)

# %%
 # Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)
distiller.compile(optimizer=keras.optimizers.Adam(),
metrics=['accuracy'],
student_loss_fn= keras.losses.BinaryCrossentropy() ,
distillation_loss_fn=keras.losses.KLDivergence(),
alpha=0.1,
temperature=10,
)

# %% [markdown]
# # Distill teacher to student

# %% [markdown]
# # Confusion Matrix Teacher

# %%
print( sep='\n')
print('DISTILL TEACHER TO STUDENT')
start_time = time.time()
kd_historyO=distiller.fit(X_trainO, y_trainO, epochs=epoch, verbose=1, validation_data=(X_testO,y_testO))
end_time = time.time()
print( sep='\n')
# Out:
# DISTILL TEACHER TO STUDENT
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.3068 - distillation_loss: 0.0015 - loss: 0.4394 - student_loss: 0.9794 - val_accuracy: 0.7027 - val_loss: 0.3646 - val_student_loss: 0.5544
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6269 - distillation_loss: 9.9486e-04 - loss: 0.4470 - student_loss: 0.6627 - val_accuracy: 0.7027 - val_loss: 0.4660 - val_student_loss: 0.3548
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7804 - distillation_loss: 7.2632e-04 - loss: 0.4915 - student_loss: 0.4963 - val_accuracy: 0.7027 - val_loss: 0.4912 - val_student_loss: 0.3138
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7815 - distillation_loss: 6.7932e-04 - loss: 0.4883 - student_loss: 0.4614 - val_accuracy: 0.7297 - val_loss: 0.4974 - val_student_loss: 0.3013
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7421 - distillation_loss: 6.3137e-04 - loss: 0.4757 - student_loss: 0.4193 - val_accuracy: 0.7568 - val_loss: 0.4996 - val_student_loss: 0.3009
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7609 - distillation_loss: 5.3275e-04 - loss: 0.4887 - student_loss: 0.3648 - val_accuracy: 0.7838 - val_loss: 0.5004 - val_student_loss: 0.2989
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8313 - distillation_loss: 5.3130e-04 - loss: 0.4934 - student_loss: 0.3666 - val_accuracy: 0.8108 - val_loss: 0.5014 - val_student_loss: 0.2967
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8193 - distillation_loss: 5.7920e-04 - loss: 0.4845 - student_loss: 0.3688 - val_accuracy: 0.8649 - val_loss: 0.5024 - val_student_loss: 0.2924
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8595 - distillation_loss: 4.7355e-04 - loss: 0.4995 - student_loss: 0.3143 - val_accuracy: 0.8649 - val_loss: 0.5026 - val_student_loss: 0.2832
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8901 - distillation_loss: 3.8051e-04 - loss: 0.4757 - student_loss: 0.2674 - val_accuracy: 0.8649 - val_loss: 0.5031 - val_student_loss: 0.2737
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8953 - distillation_loss: 3.6731e-04 - loss: 0.5017 - student_loss: 0.2635 - val_accuracy: 0.8649 - val_loss: 0.5032 - val_student_loss: 0.2642
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8950 - distillation_loss: 3.7878e-04 - loss: 0.4895 - student_loss: 0.2681 - val_accuracy: 0.8919 - val_loss: 0.5033 - val_student_loss: 0.2512
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9235 - distillation_loss: 3.6845e-04 - loss: 0.5038 - student_loss: 0.2658 - val_accuracy: 0.9189 - val_loss: 0.5037 - val_student_loss: 0.2387
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9329 - distillation_loss: 2.9913e-04 - loss: 0.4964 - student_loss: 0.2304 - val_accuracy: 0.9459 - val_loss: 0.5042 - val_student_loss: 0.2248
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9650 - distillation_loss: 2.1440e-04 - loss: 0.5020 - student_loss: 0.1814 - val_accuracy: 0.9459 - val_loss: 0.5048 - val_student_loss: 0.2110
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9837 - distillation_loss: 2.0169e-04 - loss: 0.5016 - student_loss: 0.1776 - val_accuracy: 0.9730 - val_loss: 0.5057 - val_student_loss: 0.1988
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9799 - distillation_loss: 1.6381e-04 - loss: 0.4994 - student_loss: 0.1526 - val_accuracy: 0.9730 - val_loss: 0.5060 - val_student_loss: 0.1878
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - distillation_loss: 1.2582e-04 - loss: 0.4953 - student_loss: 0.1330 - val_accuracy: 0.9730 - val_loss: 0.5064 - val_student_loss: 0.1801
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9769 - distillation_loss: 1.1557e-04 - loss: 0.5035 - student_loss: 0.1211 - val_accuracy: 0.9730 - val_loss: 0.5063 - val_student_loss: 0.1736
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9964 - distillation_loss: 1.1123e-04 - loss: 0.5025 - student_loss: 0.1215 - val_accuracy: 1.0000 - val_loss: 0.5060 - val_student_loss: 0.1716
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9892 - distillation_loss: 6.0986e-05 - loss: 0.4950 - student_loss: 0.0847 - val_accuracy: 1.0000 - val_loss: 0.5055 - val_student_loss: 0.1681
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9892 - distillation_loss: 6.0090e-05 - loss: 0.4986 - student_loss: 0.0820 - val_accuracy: 1.0000 - val_loss: 0.5054 - val_student_loss: 0.1663
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9882 - distillation_loss: 7.0904e-05 - loss: 0.5027 - student_loss: 0.0818 - val_accuracy: 1.0000 - val_loss: 0.5052 - val_student_loss: 0.1651
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - distillation_loss: 4.6837e-05 - loss: 0.5009 - student_loss: 0.0678 - val_accuracy: 1.0000 - val_loss: 0.5048 - val_student_loss: 0.1623
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 5.3453e-05 - loss: 0.5013 - student_loss: 0.0719 - val_accuracy: 1.0000 - val_loss: 0.5042 - val_student_loss: 0.1592
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - distillation_loss: 5.2339e-05 - loss: 0.5028 - student_loss: 0.0640 - val_accuracy: 1.0000 - val_loss: 0.5037 - val_student_loss: 0.1582
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9951 - distillation_loss: 3.3980e-05 - loss: 0.4987 - student_loss: 0.0536 - val_accuracy: 1.0000 - val_loss: 0.5032 - val_student_loss: 0.1548
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9902 - distillation_loss: 3.8254e-05 - loss: 0.5026 - student_loss: 0.0510 - val_accuracy: 1.0000 - val_loss: 0.5028 - val_student_loss: 0.1519
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9981 - distillation_loss: 5.1999e-05 - loss: 0.4966 - student_loss: 0.0667 - val_accuracy: 1.0000 - val_loss: 0.5027 - val_student_loss: 0.1483
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9951 - distillation_loss: 2.9368e-05 - loss: 0.5004 - student_loss: 0.0470 - val_accuracy: 1.0000 - val_loss: 0.5027 - val_student_loss: 0.1463
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9937 - distillation_loss: 4.6117e-05 - loss: 0.5008 - student_loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.5025 - val_student_loss: 0.1458
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 2.1998e-05 - loss: 0.5018 - student_loss: 0.0403 - val_accuracy: 1.0000 - val_loss: 0.5020 - val_student_loss: 0.1461
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9895 - distillation_loss: 4.8833e-05 - loss: 0.5031 - student_loss: 0.0563 - val_accuracy: 1.0000 - val_loss: 0.5013 - val_student_loss: 0.1401
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 2.4489e-05 - loss: 0.4977 - student_loss: 0.0417 - val_accuracy: 1.0000 - val_loss: 0.5008 - val_student_loss: 0.1304
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 1.7020e-05 - loss: 0.4998 - student_loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.5004 - val_student_loss: 0.1258
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 4.2084e-05 - loss: 0.5027 - student_loss: 0.0517 - val_accuracy: 1.0000 - val_loss: 0.5001 - val_student_loss: 0.1258
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - distillation_loss: 3.8180e-05 - loss: 0.5016 - student_loss: 0.0452 - val_accuracy: 1.0000 - val_loss: 0.4997 - val_student_loss: 0.1253
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9964 - distillation_loss: 3.2216e-05 - loss: 0.4964 - student_loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.4999 - val_student_loss: 0.1187
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9974 - distillation_loss: 2.9795e-05 - loss: 0.5010 - student_loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.4999 - val_student_loss: 0.1138
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9931 - distillation_loss: 3.6771e-05 - loss: 0.4992 - student_loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 0.4999 - val_student_loss: 0.1099
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - distillation_loss: 3.9033e-05 - loss: 0.5000 - student_loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.4998 - val_student_loss: 0.1072
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9931 - distillation_loss: 2.2808e-05 - loss: 0.5009 - student_loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.4997 - val_student_loss: 0.1015
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 2.7902e-05 - loss: 0.5020 - student_loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.4996 - val_student_loss: 0.0984
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 1.8311e-05 - loss: 0.4980 - student_loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 0.4997 - val_student_loss: 0.0948
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9988 - distillation_loss: 3.5348e-05 - loss: 0.4983 - student_loss: 0.0386 - val_accuracy: 1.0000 - val_loss: 0.4997 - val_student_loss: 0.0931
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - distillation_loss: 1.5284e-05 - loss: 0.5001 - student_loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 0.4996 - val_student_loss: 0.0933
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 2.3314e-05 - loss: 0.5006 - student_loss: 0.0335 - val_accuracy: 1.0000 - val_loss: 0.4995 - val_student_loss: 0.0946
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 1.3245e-05 - loss: 0.4988 - student_loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.4995 - val_student_loss: 0.0937
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9951 - distillation_loss: 1.5848e-05 - loss: 0.4987 - student_loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.4996 - val_student_loss: 0.0921
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - distillation_loss: 7.8529e-06 - loss: 0.5003 - student_loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 0.4998 - val_student_loss: 0.0913

# %%
y_predtO=teacher.predict(X_testO)

#Confusion matrix
cmO=metrics.confusion_matrix(y_testO.argmax(axis=1),y_predtO.argmax(axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
#Plot
dispO=metrics.ConfusionMatrixDisplay(confusion_matrix=cmO,display_labels=['B','M'],)
fig, ax = plt.subplots(figsize=(5,5))
dispO.plot(ax=ax);

# %% [markdown]
# ### Malignant = 2, Benign = 1

# %% [markdown]
# Lets round the values

# %% [markdown]
# # Confusion matrix student with KD

# %%
y_predsO=distiller.predict(X_testO)

#Confusion matrix
cmO=metrics.confusion_matrix(y_testO.argmax(axis=1),y_predsO.argmax(axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step

# %%
#Plot
dispO=metrics.ConfusionMatrixDisplay(confusion_matrix=cmO,display_labels=['B','M'],)
fig, ax = plt.subplots(figsize=(5,5))
dispO.plot(ax=ax);
#plt.savefig("CM3.svg")

# %%
from sklearn.metrics import roc_curve, auc

false_positive_rateO, true_positive_rateO, thresholdsO = roc_curve(y_testO.argmax(axis=1),y_predtO.argmax(axis=1))
roc_aucOt = auc(false_positive_rateO, true_positive_rateO)
roc_aucOt
# Out:
# 1.0

# %%
false_positive_rateOs, true_positive_rateOs, thresholdsOs = roc_curve(y_testO.argmax(axis=1),y_predsO.argmax(axis=1))
roc_aucOs = auc(false_positive_rateO, true_positive_rateO)
roc_aucOs
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic Curve')
plt.plot(false_positive_rateO,true_positive_rateO, color='red',label = 'TM-O AUC = %0.2f' % roc_aucOt)
plt.plot(false_positive_rateOs,true_positive_rateOs, color='green',label = 'SM-O AUC = %0.2f' % roc_aucOs)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
#plt.savefig("roc_BCT-O.svg")
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %% [markdown]
# # Function for plotting model's accuracy and loss

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,history.history['accuracy'])
  plt.plot(epochRange,history.history['val_accuracy'])
  plt.title('Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  plt.show()
  #plt.savefig("Tacc.svg")

  plt.plot(epochRange,history.history['loss'])
  plt.plot(epochRange,history.history['val_loss'])
  plt.title('Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  plt.show()
  #plt.savefig("Tloss.svg")

# %% [markdown]
# # Plotting of teacher model

# %%
plotLearningCurve(teacher_historyO,epoch)

# %% [markdown]
# # Plotting Student scratch Model

# %%
plotLearningCurve(student_scratch_historyO,epoch)

# %% [markdown]
# # Plotting knowledge distilled accuracy and loss

# %%
def plotKDCurve(history,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,history.history['accuracy'])
  plt.plot(epochRange,history.history['val_accuracy'])
  plt.title('Student Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  #plt.savefig("SmAcc.svg")
  plt.show()

  plt.plot(epochRange,history.history['student_loss'])
  plt.plot(epochRange,history.history['val_student_loss'])
  plt.title('Student Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  #plt.savefig("SmLoss.svg")
  plt.show()

# %% [markdown]
# # Plot of Student Knowldege Distilled Model

# %%
plotKDCurve(kd_historyO,epoch)

# %% [markdown]
# # Accuracy and loss of Teacher vs Student KD model

# %%
def plotKDCurveProf(his,tHis,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,tHis.history['accuracy'])
  plt.plot(epochRange,tHis.history['val_accuracy'])
  plt.plot(epochRange,his.history['accuracy'])
  plt.plot(epochRange,his.history['val_accuracy'])

  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['T_train','T_val','KD_train','KD_val'],loc='lower right')
  plt.grid(visible=True)
  plt.savefig("T-Sacc.svg")
  plt.show()


  plt.plot(epochRange,tHis.history['loss'])
  plt.plot(epochRange,tHis.history['val_loss'])
  plt.plot(epochRange,his.history['student_loss'])
  plt.plot(epochRange,his.history['val_student_loss'])
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['T_train','T_val','KD_train','KD_val'],loc='upper left')
  plt.grid(visible=True)
  plt.savefig("T-Sloss.svg")
  plt.show()

# %%
plotKDCurveProf(kd_historyO,teacher_historyO,epoch)

# %% [markdown]
#  # Student with KD Vs Student without Kd Accuracy and loss

# %%
plotKDCurveProf(kd_historyO,student_scratch_historyO,epoch)

# %% [markdown]
# # Result Summary

# %%
print("Vals. \t\t TM \t SM_scratch \t SM")
print("="*50)
print("Acc. \t\t %.2f \t %.2f \t\t %.2f"%(teacher_historyO.history['accuracy'][epoch-1],student_scratch_historyO.history['accuracy'][epoch-1],kd_historyO.history['accuracy'][epoch-1]))
print("Val. Acc. \t %.2f \t %.2f \t\t %.2f"%(teacher_historyO.history['val_accuracy'][epoch-1],student_scratch_historyO.history['val_accuracy'][epoch-1],kd_historyO.history['val_accuracy'][epoch-1]))
print("Loss. \t\t %.2f \t %.2f \t\t %.2f"%(teacher_historyO.history['loss'][epoch-1],student_scratch_historyO.history['loss'][epoch-1],kd_historyO.history['loss'][epoch-1]))
print("Val. Loss. \t %.2f \t %.2f \t\t %.2f"%(teacher_historyO.history['val_loss'][epoch-1],student_scratch_historyO.history['val_loss'][epoch-1],kd_historyO.history['val_loss'][epoch-1]))
# Out:
# Vals. 		 TM 	 SM_scratch 	 SM
# ==================================================
# Acc. 		 1.00 	 0.84 		 1.00
# Val. Acc. 	 1.00 	 0.86 		 1.00
# Loss. 		 0.00 	 0.41 		 0.50
# Val. Loss. 	 0.01 	 0.39 		 0.50
