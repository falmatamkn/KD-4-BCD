# %% [markdown]
# # Introduction
# This code tests the proposed model on Wisconsin Breast Cancer Database (https://www.kaggle.com/datasets/roustekbio/breast-cancer-csv).

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %matplotlib inline 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, MaxPool1D,Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils



#Import models from scikit learn module:
from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


#For timing the simulation
import time

# %% [markdown]
# # Parameters

# %%
epoch=30

# %% [markdown]
# # Loading BCD Data

# %%
#load dataset
data = pd.read_csv("/kaggle/input/bcd-dt/breastCancer.csv",header = 0)
data.head(5)
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# 3                7        1      2
# 4                1        1      2

# %% [markdown]
# # Data Preprocessing

# %%
print(data['class'].value_counts())
plt.title('Count of cancer type')
sns.countplot(data['class'])
plt.ylabel('Count')
plt.show()
# Out:
# class
# 2    458
# 4    241
# Name: count, dtype: int64

# %%
#clean and prepare data
data.drop('id',axis=1,inplace=True)

# size of the dataframe
len(data)
# Out:
# 699

# %%
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# class                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   clump_thickness    699 non-null    int64
#  1   size_uniformity    699 non-null    int64
#  2   shape_uniformity   699 non-null    int64
#  3   marginal_adhesion  699 non-null    int64
#  4   epithelial_size    699 non-null    int64
#  5   bare_nucleoli      699 non-null    object
#  6   bland_chromatin    699 non-null    int64
#  7   normal_nucleoli    699 non-null    int64
#  8   mitoses            699 non-null    int64
#  9   class              699 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 54.7+ KB

# %% [markdown]
# ## Lets remove "?" in column 7 to have int dtype

# %%
(data['bare_nucleoli']== '?').sum()
# Out:
# 16

# %%
data = data[data.bare_nucleoli != '?']
len(data)
# Out:
# 683

# %%
data=data.astype({"bare_nucleoli":int})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 683 entries, 0 to 698
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   clump_thickness    683 non-null    int64
#  1   size_uniformity    683 non-null    int64
#  2   shape_uniformity   683 non-null    int64
#  3   marginal_adhesion  683 non-null    int64
#  4   epithelial_size    683 non-null    int64
#  5   bare_nucleoli      683 non-null    int64
#  6   bland_chromatin    683 non-null    int64
#  7   normal_nucleoli    683 non-null    int64
#  8   mitoses            683 non-null    int64
#  9   class              683 non-null    int64
# dtypes: int64(10)
# memory usage: 58.7 KB

# %%
print(data['class'].value_counts())
# Out:
# class
# 2    444
# 4    239
# Name: count, dtype: int64

# %% [markdown]
# ## Proper labeling
#
# The classes are 2 and 4, lets make them 0, 1, making the label better

# %%
Y=data['class']
Y=Y.map({2:0,4:1})

print(Y.shape)
print(type(Y))
# Out:
# (683,)
# <class 'pandas.core.series.Series'>

# %%
data.drop('class',axis=1,inplace=True)
X=data
del data

# %%
Y1=pd.DataFrame(Y)
print(Y1.value_counts())
# Out:
# class
# 0        444
# 1        239
# Name: count, dtype: int64

# %% [markdown]
# ## Creating one-hot class

# %%
Y = utils.to_categorical(Y, num_classes=2)

# %% [markdown]
# ## Split train and test dataset

# %%
X_train,X_test,y_train,y_test= train_test_split(X,Y,test_size=0.15,stratify=Y)

# %%
y_test.shape
# Out:
# (103, 2)

# %% [markdown]
# ## Scaling

# %%
scaler=StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#         [ 0.20079682, -0.7030999 , -0.73412578, -0.63920245, -0.55291983,
#          -0.70291267, -0.58611513, -0.61295579, -0.34190007],
#         [-1.2194734 , -0.7030999 , -0.73412578, -0.63920245, -0.55291983,
#          -0.70291267, -0.58611513, -0.61295579, -0.34190007],
#         [ 0.91093194,  1.62717405,  1.31295571, -0.29433043,  0.34538129,
#           1.20983897, -0.17154589,  1.7041769 ,  0.24479236],
#         [ 0.20079682, -0.7030999 , -0.73412578, -0.63920245, -1.00207039,
#          -0.70291267, -0.17154589, -0.61295579, -0.34190007],
#         [ 0.20079682, -0.7030999 , -0.05176528, -0.63920245, -0.55291983,
#          -0.70291267, -0.58611513, -0.61295579, -0.34190007],
#         [-0.86440584, -0.7030999 , -0.73412578, -0.63920245, -0.55291983,
#          -0.70291267, -0.17154589, -0.61295579, -0.34190007],
#         [ 0.20079682, -0.7030999 , -0.73412578, -0.63920245, -0.55291983,
#          -0.70291267, -1.00068438, -0.61295579, -0.34190007],
#         [-1.2194734 , -0.37020362, -0.39294553, -0.63920245, -0.55291983,
#          -0.70291267, -1.00068438, -0.61295579, -0.34190007],
#         [-0.86440584, -0.7030999 , -0.73412578, -0.63920245, -0.55291983,
#          -0.70291267, -0.58611513, -0.61295579, -0.34190007],
#         [ 0.91093194,  0.96138149, -0.05176528, -0.29433043,  0.79453186,
#           1.75633945,  1.48673107,  0.38010108,  2.59156211]]))

# %% [markdown]
# ## Reshaping
# Reshaping the data set to 3D to pass it through CNN

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((580, 9), (103, 9), (580, 2), (103, 2))

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %% [markdown]
# # Create teacher and student model

# %%
# Create the teacher
teacher =keras.Sequential()
teacher.add(keras.Input(shape=(X_train.shape[1],1)))
teacher.add(keras.layers.Conv1D(filters=64,kernel_size= 2,activation='relu'))
teacher.add(keras.layers.BatchNormalization())
teacher.add(keras.layers.Dropout(0.2))
        
teacher.add(keras.layers.Conv1D(448, 2,activation='relu'))
teacher.add(keras.layers.BatchNormalization())
teacher.add(keras.layers.Dropout(0.2))
        
teacher.add(keras.layers.Flatten())
teacher.add(keras.layers.Dense(64,activation='relu'))
teacher.add(keras.layers.Dropout(0.2))

teacher.add(keras.layers.Dense(2,activation='sigmoid'))

teacher.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',
              metrics=['accuracy'])


# Create the student
student = keras.Sequential(
    [
        keras.Input(shape=(X_train.shape[1], 1)),
        layers.Conv1D(4, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
       # layers.LeakyReLU(alpha=0.2),
        
        layers.Conv1D(8, 2),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        
        layers.Flatten(),
        layers.Dense(2,activation='sigmoid'),
    ],
    name="student",)
    

# Clone student for later comparison
student_scratch = keras.models.clone_model(student)

#compile STUDENT
student_scratch.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',
              metrics=['accuracy'])
print( sep='\n')
print('STUDENT')
# Out:
# STUDENT

# %% [markdown]
# Lets make a copy of the student model for comparion

# %%
teacher.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 8, 64)          │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 8, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 7, 448)         │        57,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 448)         │         1,792 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 448)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       200,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 260,930 (1019.26 KB)
#  Trainable params: 259,906 (1015.26 KB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
student.summary()
# Out:
# Model: "student"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 8, 4)           │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 4)           │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 4)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 7, 8)           │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7, 8)           │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 7, 8)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 56)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           114 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 246 (984.00 B)
#  Trainable params: 222 (888.00 B)
#  Non-trainable params: 24 (96.00 B)

# %% [markdown]
# # Train teacher model

# %%
start_time = time.time()
teacher_history=teacher.fit(X_train,y_train,epochs=epoch,validation_data=(X_test,y_test),verbose=1)
end_time = time.time()
print( sep='\n')
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7455 - loss: 0.5480 - val_accuracy: 0.9903 - val_loss: 0.5897
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9539 - loss: 0.1487 - val_accuracy: 0.9806 - val_loss: 0.5377
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9740 - loss: 0.1077 - val_accuracy: 0.9223 - val_loss: 0.4977
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9583 - loss: 0.1223 - val_accuracy: 0.8544 - val_loss: 0.4640
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9593 - loss: 0.1062 - val_accuracy: 0.8544 - val_loss: 0.4269
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9701 - loss: 0.0986 - val_accuracy: 0.8544 - val_loss: 0.3928
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9651 - loss: 0.1291 - val_accuracy: 0.8544 - val_loss: 0.3605
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9544 - loss: 0.1145 - val_accuracy: 0.8544 - val_loss: 0.3316
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9694 - loss: 0.0788 - val_accuracy: 0.8835 - val_loss: 0.2976
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9757 - loss: 0.0822 - val_accuracy: 0.8932 - val_loss: 0.2736
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9677 - loss: 0.0784 - val_accuracy: 0.9223 - val_loss: 0.2382
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9642 - loss: 0.0950 - val_accuracy: 0.9223 - val_loss: 0.2205
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9668 - loss: 0.0753 - val_accuracy: 0.9806 - val_loss: 0.1868
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9718 - loss: 0.0764 - val_accuracy: 0.9903 - val_loss: 0.1582
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9822 - loss: 0.0691 - val_accuracy: 0.9903 - val_loss: 0.1324
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9770 - loss: 0.0750 - val_accuracy: 0.9903 - val_loss: 0.1172
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9733 - loss: 0.0644 - val_accuracy: 0.9903 - val_loss: 0.1086
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9739 - loss: 0.0830 - val_accuracy: 0.9903 - val_loss: 0.0897
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9627 - loss: 0.0841 - val_accuracy: 0.9903 - val_loss: 0.0783
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9796 - loss: 0.0670 - val_accuracy: 0.9903 - val_loss: 0.0682
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9680 - loss: 0.0694 - val_accuracy: 1.0000 - val_loss: 0.0550
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9805 - loss: 0.0602 - val_accuracy: 1.0000 - val_loss: 0.0456
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9593 - loss: 0.0858 - val_accuracy: 1.0000 - val_loss: 0.0425
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9800 - loss: 0.0671 - val_accuracy: 1.0000 - val_loss: 0.0359
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9759 - loss: 0.0553 - val_accuracy: 1.0000 - val_loss: 0.0332
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9730 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 0.0396
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9785 - loss: 0.0561 - val_accuracy: 1.0000 - val_loss: 0.0329
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9797 - loss: 0.0607 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9766 - loss: 0.0620 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.0585 - val_accuracy: 1.0000 - val_loss: 0.0248

# %%
teacher.evaluate(X_test,y_test)
print("Execution time: ", end_time - start_time,"secs")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0228
# Execution time:  9.434224843978882 secs

# %% [markdown]
# # Student Model without KD Training

# %%
start_time = time.time()
student_scratch_history=student_scratch.fit(X_train,y_train,epochs=epoch,validation_data=(X_test,y_test),verbose=1)
end_time = time.time()
print( sep='\n')
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7692 - loss: 0.6375 - val_accuracy: 0.9903 - val_loss: 0.5412
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8638 - loss: 0.5599 - val_accuracy: 1.0000 - val_loss: 0.5156
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8852 - loss: 0.5453 - val_accuracy: 1.0000 - val_loss: 0.4908
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8852 - loss: 0.5463 - val_accuracy: 1.0000 - val_loss: 0.4653
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8846 - loss: 0.5243 - val_accuracy: 1.0000 - val_loss: 0.4400
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9100 - loss: 0.4891 - val_accuracy: 1.0000 - val_loss: 0.4163
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8899 - loss: 0.4834 - val_accuracy: 1.0000 - val_loss: 0.3929
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9087 - loss: 0.4787 - val_accuracy: 1.0000 - val_loss: 0.3699
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9268 - loss: 0.4291 - val_accuracy: 1.0000 - val_loss: 0.3483
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.4335 - val_accuracy: 1.0000 - val_loss: 0.3281
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9376 - loss: 0.4086 - val_accuracy: 1.0000 - val_loss: 0.3088
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9504 - loss: 0.3564 - val_accuracy: 1.0000 - val_loss: 0.2916
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9235 - loss: 0.3943 - val_accuracy: 1.0000 - val_loss: 0.2742
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9475 - loss: 0.3627 - val_accuracy: 1.0000 - val_loss: 0.2582
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9504 - loss: 0.3356 - val_accuracy: 1.0000 - val_loss: 0.2429
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.3303 - val_accuracy: 1.0000 - val_loss: 0.2298
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9562 - loss: 0.3122 - val_accuracy: 1.0000 - val_loss: 0.2176
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9626 - loss: 0.3000 - val_accuracy: 1.0000 - val_loss: 0.2063
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.3010 - val_accuracy: 1.0000 - val_loss: 0.1968
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9580 - loss: 0.2838 - val_accuracy: 1.0000 - val_loss: 0.1873
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9613 - loss: 0.2731 - val_accuracy: 1.0000 - val_loss: 0.1779
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9457 - loss: 0.2835 - val_accuracy: 1.0000 - val_loss: 0.1696
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.2936 - val_accuracy: 1.0000 - val_loss: 0.1618
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9401 - loss: 0.2725 - val_accuracy: 0.9903 - val_loss: 0.1542
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9529 - loss: 0.2643 - val_accuracy: 0.9903 - val_loss: 0.1478
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9511 - loss: 0.2663 - val_accuracy: 0.9903 - val_loss: 0.1415
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9515 - loss: 0.2621 - val_accuracy: 0.9903 - val_loss: 0.1353
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9695 - loss: 0.2308 - val_accuracy: 0.9903 - val_loss: 0.1299
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9499 - loss: 0.2392 - val_accuracy: 0.9903 - val_loss: 0.1240
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9607 - loss: 0.2185 - val_accuracy: 0.9903 - val_loss: 0.1193

# %%
student_scratch.evaluate(X_test,y_test)
print("Execution time: ", end_time - start_time,"secs")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.1197
# Execution time:  5.867706298828125 secs

# %% [markdown]
# # Knowledge Distillation
# ## Construct distiller class

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)
            distillation_loss = self.distillation_loss_fn(
                tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                tf.nn.softmax(student_predictions / self.temperature, axis=1),
            )
            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results
    
    def call(self, x):
        return self.student(x)

# %%
 # Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)
distiller.compile(optimizer=keras.optimizers.Adam(),
metrics=['accuracy'],
student_loss_fn= keras.losses.BinaryCrossentropy() ,
distillation_loss_fn=keras.losses.KLDivergence(),
alpha=0.1,
temperature=10,
)

# %% [markdown]
# ## Distill teacher to student

# %%
print( sep='\n')
print('DISTILL TEACHER TO STUDENT')
start_time = time.time()
kd_history=distiller.fit(X_train, y_train, epochs=epoch, verbose=1, validation_data=(X_test,y_test))
end_time = time.time()
print( sep='\n')
# Out:
# DISTILL TEACHER TO STUDENT
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:578: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.3479 - distillation_loss: 0.0013 - loss: 0.4895 - student_loss: 0.9068 - val_accuracy: 0.9806 - val_loss: 0.5000 - val_student_loss: 0.4952
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7295 - distillation_loss: 6.9328e-04 - loss: 0.5049 - student_loss: 0.5702 - val_accuracy: 0.9903 - val_loss: 0.4972 - val_student_loss: 0.3909
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9047 - distillation_loss: 3.2749e-04 - loss: 0.5000 - student_loss: 0.3533 - val_accuracy: 0.9903 - val_loss: 0.4971 - val_student_loss: 0.3005
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9559 - distillation_loss: 2.5420e-04 - loss: 0.5055 - student_loss: 0.3076 - val_accuracy: 0.9903 - val_loss: 0.4983 - val_student_loss: 0.2283
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - distillation_loss: 1.7109e-04 - loss: 0.4925 - student_loss: 0.2848 - val_accuracy: 0.9903 - val_loss: 0.4994 - val_student_loss: 0.1801
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9509 - distillation_loss: 1.0537e-04 - loss: 0.5038 - student_loss: 0.1830 - val_accuracy: 0.9903 - val_loss: 0.5003 - val_student_loss: 0.1472
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9581 - distillation_loss: 9.7838e-05 - loss: 0.4997 - student_loss: 0.1625 - val_accuracy: 0.9903 - val_loss: 0.5007 - val_student_loss: 0.1189
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9443 - distillation_loss: 1.0695e-04 - loss: 0.4993 - student_loss: 0.1806 - val_accuracy: 0.9903 - val_loss: 0.5010 - val_student_loss: 0.0971
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9590 - distillation_loss: 1.1335e-04 - loss: 0.4932 - student_loss: 0.1830 - val_accuracy: 0.9903 - val_loss: 0.5015 - val_student_loss: 0.0801
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9624 - distillation_loss: 7.0977e-05 - loss: 0.4990 - student_loss: 0.1344 - val_accuracy: 0.9903 - val_loss: 0.5016 - val_student_loss: 0.0695
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9737 - distillation_loss: 7.0236e-05 - loss: 0.4988 - student_loss: 0.1297 - val_accuracy: 0.9903 - val_loss: 0.5018 - val_student_loss: 0.0588
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9464 - distillation_loss: 1.4895e-04 - loss: 0.4993 - student_loss: 0.2193 - val_accuracy: 0.9903 - val_loss: 0.5022 - val_student_loss: 0.0502
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9605 - distillation_loss: 6.7895e-05 - loss: 0.4954 - student_loss: 0.1300 - val_accuracy: 0.9903 - val_loss: 0.5023 - val_student_loss: 0.0478
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9569 - distillation_loss: 8.1118e-05 - loss: 0.5005 - student_loss: 0.1276 - val_accuracy: 0.9903 - val_loss: 0.5023 - val_student_loss: 0.0412
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9638 - distillation_loss: 1.6482e-04 - loss: 0.4962 - student_loss: 0.2303 - val_accuracy: 0.9903 - val_loss: 0.5023 - val_student_loss: 0.0364
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9654 - distillation_loss: 7.9066e-05 - loss: 0.4983 - student_loss: 0.1315 - val_accuracy: 0.9903 - val_loss: 0.5023 - val_student_loss: 0.0331
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9502 - distillation_loss: 9.1633e-05 - loss: 0.4975 - student_loss: 0.1587 - val_accuracy: 0.9903 - val_loss: 0.5025 - val_student_loss: 0.0308
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - distillation_loss: 1.3414e-04 - loss: 0.4983 - student_loss: 0.1609 - val_accuracy: 0.9903 - val_loss: 0.5026 - val_student_loss: 0.0270
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9501 - distillation_loss: 7.1468e-05 - loss: 0.4981 - student_loss: 0.1399 - val_accuracy: 0.9903 - val_loss: 0.5025 - val_student_loss: 0.0253
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9515 - distillation_loss: 7.0920e-05 - loss: 0.4964 - student_loss: 0.1271 - val_accuracy: 0.9903 - val_loss: 0.5022 - val_student_loss: 0.0236
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9575 - distillation_loss: 7.5067e-05 - loss: 0.4986 - student_loss: 0.1229 - val_accuracy: 0.9903 - val_loss: 0.5020 - val_student_loss: 0.0218
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9434 - distillation_loss: 1.3068e-04 - loss: 0.4969 - student_loss: 0.1934 - val_accuracy: 0.9903 - val_loss: 0.5019 - val_student_loss: 0.0194
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9487 - distillation_loss: 6.4398e-05 - loss: 0.4990 - student_loss: 0.1216 - val_accuracy: 0.9903 - val_loss: 0.5016 - val_student_loss: 0.0178
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9621 - distillation_loss: 5.8970e-05 - loss: 0.4985 - student_loss: 0.1206 - val_accuracy: 0.9903 - val_loss: 0.5016 - val_student_loss: 0.0161
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9579 - distillation_loss: 5.9812e-05 - loss: 0.4961 - student_loss: 0.1138 - val_accuracy: 0.9903 - val_loss: 0.5016 - val_student_loss: 0.0149
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9577 - distillation_loss: 9.9684e-05 - loss: 0.4982 - student_loss: 0.1446 - val_accuracy: 0.9903 - val_loss: 0.5017 - val_student_loss: 0.0142
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9494 - distillation_loss: 8.8168e-05 - loss: 0.4976 - student_loss: 0.1312 - val_accuracy: 0.9903 - val_loss: 0.5018 - val_student_loss: 0.0137
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9573 - distillation_loss: 8.4983e-05 - loss: 0.5004 - student_loss: 0.1314 - val_accuracy: 0.9903 - val_loss: 0.5017 - val_student_loss: 0.0126
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9645 - distillation_loss: 4.8543e-05 - loss: 0.4989 - student_loss: 0.1155 - val_accuracy: 0.9903 - val_loss: 0.5016 - val_student_loss: 0.0120
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9495 - distillation_loss: 5.4181e-05 - loss: 0.4999 - student_loss: 0.1126 - val_accuracy: 0.9903 - val_loss: 0.5016 - val_student_loss: 0.0117

# %%
distiller.evaluate(X_test,y_test)
print("Execution time: ", end_time - start_time,"secs")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.5016 - student_loss: 0.0204
# Execution time:  6.787606239318848 secs

# %% [markdown]
# # Confusion Matrix Teacher

# %%
y_predt=teacher.predict(X_test)

#Confusion matrix
cm=metrics.confusion_matrix(y_test.argmax(axis=1),y_predt.argmax(axis=1))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
#Plot
disp=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['B','M'],)
fig, ax = plt.subplots(figsize=(5,5))
disp.plot(ax=ax);

# %% [markdown]
# # Confusion Matrix Student with KD

# %%
y_preds=distiller.predict(X_test)

#Confusion matrix
cm=metrics.confusion_matrix(y_test.argmax(axis=1),y_preds.argmax(axis=1))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
#Plot
disp=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['B','M'],)
fig, ax = plt.subplots(figsize=(5,5))
disp.plot(ax=ax);

#plt.savefig("CM2.svg")

# %%
auc_roc=metrics.roc_auc_score(y_test.argmax(axis=1),y_preds.argmax(axis=1))
auc_roc
# Out:
# 0.9925373134328358

# %%
from sklearn.metrics import roc_curve, auc

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test.argmax(axis=1),y_preds.argmax(axis=1))
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9925373134328358

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic Curve')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("roc2.svg")

# %% [markdown]
# # Plots of accuracy and loss

# %% [markdown]
# ## Accuracy and loss function

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,history.history['accuracy'])
  plt.plot(epochRange,history.history['val_accuracy'])
  plt.title('Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  plt.show()
  #plt.savefig("Tacc.svg")

  plt.plot(epochRange,history.history['loss'])
  plt.plot(epochRange,history.history['val_loss'])
  plt.title('Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  plt.show()
  #plt.savefig("Tloss.svg")

# %% [markdown]
# ## Plot of teacher

# %%
plotLearningCurve(teacher_history,epoch)

# %% [markdown]
# ## KD accuracy and loss function

# %%
def plotKDCurve(history,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,history.history['accuracy'])
  plt.plot(epochRange,history.history['val_accuracy'])
  plt.title('Student Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  plt.savefig("SmAcc.svg")
  plt.show()

  plt.plot(epochRange,history.history['student_loss'])
  plt.plot(epochRange,history.history['val_student_loss'])
  plt.title('Student Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.grid(visible=True)
  plt.savefig("SmLoss.svg")
  plt.show()

# %% [markdown]
# ## Plot of Student Model with KD

# %%
plotKDCurve(kd_history,epoch)

# %% [markdown]
# ## Plotting Student scratch Model

# %%
plotLearningCurve(student_scratch_history,epoch)

# %% [markdown]
# ## Accuracy and loss of Teacher vs Student KD model

# %%
def plotKDCurveProf(his,tHis,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,tHis.history['accuracy'])
  plt.plot(epochRange,tHis.history['val_accuracy'])
  plt.plot(epochRange,his.history['accuracy'])
  plt.plot(epochRange,his.history['val_accuracy'])

  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['T_train','T_val','KD_train','KD_val'],loc='lower right')
  plt.grid(visible=True)
  plt.savefig("T-Sacc.svg")
  plt.show()


  plt.plot(epochRange,tHis.history['loss'])
  plt.plot(epochRange,tHis.history['val_loss'])
  plt.plot(epochRange,his.history['student_loss'])
  plt.plot(epochRange,his.history['val_student_loss'])
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['T_train','T_val','KD_train','KD_val'],loc='upper left')
  plt.grid(visible=True)
  plt.savefig("T-Sloss.svg")
  plt.show()

# %%
plotKDCurveProf(kd_history,teacher_history,epoch)

# %% [markdown]
#  ## Student with KD Vs Student without Kd Accuracy and loss

# %%
plotKDCurveProf(kd_history,student_scratch_history,epoch)

# %% [markdown]
# # Results Summary

# %%
print("Vals. \t\t TM \t SM_scratch \t SM")
print("="*50)
print("Acc. \t\t %.2f \t %.2f \t\t %.2f"%(teacher_history.history['accuracy'][epoch-1],student_scratch_history.history['accuracy'][epoch-1],kd_history.history['accuracy'][epoch-1]))
print("Val. Acc. \t %.2f \t %.2f \t\t %.2f"%(teacher_history.history['val_accuracy'][epoch-1],student_scratch_history.history['val_accuracy'][epoch-1],kd_history.history['val_accuracy'][epoch-1]))
print("Loss. \t\t %.2f \t %.2f \t\t %.2f"%(teacher_history.history['loss'][epoch-1],student_scratch_history.history['loss'][epoch-1],kd_history.history['loss'][epoch-1]))
print("Val. Loss. \t %.2f \t %.2f \t\t %.2f"%(teacher_history.history['val_loss'][epoch-1],student_scratch_history.history['val_loss'][epoch-1],kd_history.history['val_loss'][epoch-1]))
# Out:
# Vals. 		 TM 	 SM_scratch 	 SM
# ==================================================
# Acc. 		 0.98 	 0.96 		 0.96
# Val. Acc. 	 1.00 	 0.99 		 0.99
# Loss. 		 0.06 	 0.24 		 0.50
# Val. Loss. 	 0.02 	 0.12 		 0.50
